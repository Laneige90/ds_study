# %% [markdown]
# ## Selenium

# %% [markdown]
# - 웹 브라우저를 원격으로 조작하는 도구
# - 자동으로 URL을 열고 클릭 등의 행동이 가능
# - 스크롤, 문자의 입력, 화면 캡처 등

# %% [markdown]
# ### selenium을 사용하는 이유

# %% [markdown]
# Beautiful soup 으로 해결할 수 없는 상황
# - 접근할 웹 주소를 알 수 없을 때
# - 자바 스크립트를 사용하는 웹페이지
# - 웹 브라우저로 접근하면 안되는 상황일때

# %%
from selenium import webdriver

# %%
driver = webdriver.Chrome('D:/ds_study/driver/chromedriver.exe')
driver.get('http://www.naver.com')

# %%
driver.quit()

# %%
# 스크롤 가능한 높이
last_height = driver.execute_script('return document.body.scrollHeight')
last_height
# Out:
# 2786

# %%
# 스크롤 제어
from selenium.webdriver import ActionChains

some_tag = driver.find_element_by_xpath('''//*[@id="newsstand"]/div[4]''') # 기준 대상의 xpath

action = ActionChains(driver)
action.move_to_element(some_tag).perform()

# %%
# 검색창에 검색어 입력
some_tag = driver.find_element_by_id('''query''')
some_tag.send_keys('꽁차이 요리')

# %%
# 검색 버튼 클릭
xpath = '''//*[@id="sform"]/fieldset/button''' # 검색 버튼의 xpath
some_tag = driver.find_element_by_xpath(xpath).click()

# %%
# 현재 화면의 html 코드 출력
from bs4 import BeautifulSoup

req = driver.page_source
soup = BeautifulSoup(req, 'html.parser')

# %%
soup
# Out:
# <html data-platform="win32" data-useragent="mozilla/5.0 (windows nt 10.0; win64; x64) applewebkit/537.36 (khtml, like gecko) chrome/114.0.0.0 safari/537.36" lang="ko"><head> <meta charset="utf-8"/> <meta content="always" name="referrer"/> <meta content="telephone=no,address=no,email=no" name="format-detection"/> <meta content="width=device-width,initial-scale=1.0,maximum-scale=2.0" name="viewport"/> <meta content="꽁차이 요리 : 네이버 통합검색" property="og:title"/> <meta content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png" property="og:image"/> <meta content="'꽁차이 요리'의 네이버 통합검색 결과입니다." property="og:description"/> <meta content="'꽁차이 요리'의 네이버 통합검색 결과입니다." lang="ko" name="description"/> <title>꽁차이 요리 : 네이버 통합검색</title> <link href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_191118_pc.ico" rel="shortcut icon"/> <link href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" rel="search" title="Naver" type="application/opensearchdescription+xml"/><link h
# ...
